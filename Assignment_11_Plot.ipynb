# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
times = [4.929200076730922e-05,
          6.201199721544981e-05,
          7.262000144692138e-05,
          0.008716819000255782,
          0.012013962004857603,
          0.048471166999661364,
          0.0832864990006783,
          0.17910748500435147]

processes = [1,2,3,6,12,24,48,96]

# %%
fig = plt.figure(figsize=(6,4))
plt.loglog(processes,times)
plt.title('Parallel run time scaling',fontsize=16)
plt.ylabel('Run time (s)',fontsize=14)
plt.xlabel('Number of processes',fontsize=14);
